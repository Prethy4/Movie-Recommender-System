# %%
import numpy as np
import pandas as pd

# %%
credits = pd.read_csv('../credits.csv')

# %%
movie = pd.read_csv('../movies_metadata.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4216\2121734989.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie = pd.read_csv('../movies_metadata.csv')

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# movie.head()

# %%
movie.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
print("credits: ", credits.shape)
print("Movie DF: ", movie.shape)
# Out:
# credits:  (45476, 3)
# Movie DF:  (45466, 24)

# %%
#credit_rename = credits.rename(index=str, columns={'ID':'id'})
#merged_df = pd.merge(df1, df2, on='id', how='inner')
credits['id'] = credits['id'].astype(str)
movie['id'] = movie['id'].astype(str)
movie_marge = pd.merge(credits, movie, on='id')
movie_marge.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  adult  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862  False
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844  False
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602  False
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357  False
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862  False
#
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# ...

# %%
movie_marge1 = movie_marge.head(50)
movie_marge1_r = movie_marge1.reset_index(drop=True)

# %%
movie_marge1_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cast                   50 non-null     object
#  1   crew                   50 non-null     object
#  2   id                     50 non-null     object
#  3   adult                  50 non-null     object
#  4   belongs_to_collection  10 non-null     object
#  5   budget                 50 non-null     object
#  6   genres                 50 non-null     object
#  7   homepage               5 non-null      object
#  8   imdb_id                50 non-null     object
#  9   original_language      50 non-null     object
#  10  original_title         50 non-null     object
#  11  overview               49 non-null     object
#  12  popularity             50 non-null     object
#  13  poster_path            50 non-null     object
# ...

# %%
movie_marge1_r.head(1)['overview']
# Out:
# 0    Led by Woody, Andy's toys live happily in his ...
# Name: overview, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer(min_df=3, max_features=None, strip_accents='unicode', analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,3), stop_words='english')
    
movie_marge1_r['overview']=movie_marge1_r['overview'].fillna('')

# %%
tf_matrix = tf.fit_transform(movie_marge1_r['overview'])

# %%
tf_matrix
# Out:
# <50x49 sparse matrix of type '<class 'numpy.float64'>'
# 	with 193 stored elements in Compressed Sparse Row format>

# %%
tf_matrix.shape
# Out:
# (50, 49)

# %%
from scipy.sparse import csr_matrix

# Assuming tf_matrix is a dense matrix
sparse_tf_matrix = csr_matrix(tf_matrix)

# %%
from sklearn.metrics.pairwise import sigmoid_kernel
sig = sigmoid_kernel(tf_matrix, tf_matrix)

# %%
sig[0]
# Out:
# array([0.77003273, 0.764181  , 0.76330508, 0.76159416, 0.76545353,
#        0.76159416, 0.76159416, 0.76159416, 0.76219155, 0.76159416,
#        0.76598086, 0.76353923, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.76920435, 0.76321425, 0.76159416,
#        0.7642195 , 0.76159416, 0.76159416, 0.76159416, 0.76159416,
#        0.76159416, 0.76159416, 0.7633808 , 0.76159416, 0.76327054,
#        0.76159416, 0.7634628 , 0.76159416, 0.76440581, 0.76432923,
#        0.76159416, 0.76225095, 0.76732135, 0.7629297 , 0.76159416,
#        0.76732135, 0.76159416, 0.76271868, 0.76159416, 0.76159416,
#        0.76320534, 0.76262034, 0.76398123, 0.76159416, 0.76414169])

# %%
indics = pd.Series(movie_marge1_r.index, index=movie_marge1_r['title']).drop_duplicates()

# %%
indics
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
# Heat                               5
# Sabrina                            6
# Tom and Huck                       7
# Sudden Death                       8
# GoldenEye                          9
# The American President            10
# Dracula: Dead and Loving It       11
# Balto                             12
# Nixon                             13
# Cutthroat Island                  14
# Casino                            15
# Sense and Sensibility             16
# Four Rooms                        17
# Ace Ventura: When Nature Calls    18
# Money Train                       19
# Get Shorty                        20
# Copycat                           21
# Assassins                         22
# Powder                            23
# Leaving Las Vegas                 24
# ...
